# %%
#imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv('./TaxiData.csv')
df
# Out:
#        pickup_community_area   fare  trip_start_month  trip_start_hour  \
# 0                        NaN  12.45                 5               19
# 1                        NaN   0.00                 3               19
# 2                       60.0  27.05                10                2
# 3                       10.0   5.85                10                1
# 4                       14.0  16.65                 5                7
# ...                      ...    ...               ...              ...
# 14997                    8.0   3.25                 5               11
# 14998                    8.0   3.25                11               16
# 14999                    8.0   4.25                12               13
# 15000                   61.0   9.85                 9               15
# 15001                    8.0   7.45                 7               11
#
#        trip_start_day  trip_start_timestamp  pickup_latitude  \
# ...

# %% [markdown]
# ## Q 2.a)
# Trip Frequency by Time of Day, Month, and Day
